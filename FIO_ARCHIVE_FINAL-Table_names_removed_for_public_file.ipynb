# %%
#This is probably the weirdest way I've ever had to go about solving a problem. 
#The Problem: Urgent Data Request - I need to fill out 2 remaining columns in an Excel file. 
#The issue is there were tons of transformations done in the excel file, and I do not know what they are, 
#so it would be nearly impossible to write a SQL query for all unknown conditions and match all 4674 rows. 
#There is also a lot of dirty data in some of these fields in our warehouse around some of these fields
#(Legal entity duplicates causing many to many relationships)
#The Solution: Write a query for each row.

# %%
import pandas as pd
import pyodbc 
import matplotlib as plt

#Change Jupyter io limit to 1M to make sure all queries are being generated (100,000 lines is the default limit)
#--NotebookApp.iopub_data_rate_limit=1000000000
# %matplotlib inline

# %%
#establish MS DB Connection
cnxn = pyodbc.connect('DRIVER={SQL Server};SERVER=serveraddress;DATABASE=dbname;UID=user;PWD=pass')
#create Cursor
cursor = cnxn.cursor()

# %%
#get file and transform to data frame
f = open('C:\Users\\pathtofile\file.csv')
inputFile = pd.read_csv(f)
df = pd.DataFrame(inputFile)
f.close()

# %%
df.head()
#Can't show data publicly

# %%
queryFile = open('C:\Users\\pathtofile\file.csv', 'w')

# %%
#Writes queries to text file with a pipe delimiter. One query per row in csv file. 
#The reason it had to be written like this is dirty data. 
#The legal entity IDs are attributed to many names and different spellings making a 'like' clause impossible 

row_iterator = df.iterrows()
_, last = row_iterator.next()  # take first item from row_iterator

for i, row in row_iterator:
    row1 = (int(row['LEGAL_ENTITY']), int(row['CY_YE']), int(row['TRIP_ASLOB']), row['CVG_ST'])
    row2 = (last['LEGAL_ENTITY'], last['CY_YE'], last['TRIP_ASLOB'], last['CVG_ST'])
    last = row
    data = row1

    
    query= """USE xxx
    DECLARE @xxx TABLE (Value VARCHAR(MAX))
    
    INSERT INTO @xxx VALUES ('xxx') 
    INSERT INTO @xxx VALUES ('xxx') 
    
    DECLARE @xxx TABLE (Value VARCHAR(MAX))
    
    INSERT INTO @xxx VALUES ('xxx') 
    INSERT INTO @xxx VALUES ('xxx') 
    
    DECLARE @bric TABLE (Value VARCHAR(MAX))
    
    INSERT INTO @xxx VALUES ('xxx')
    INSERT INTO @xxx VALUES ('xxx') 
    INSERT INTO @xxx VALUES ('xxx') 
    
    DECLARE @xxx TABLE (Value VARCHAR(MAX))
    INSERT INTO @xxx VALUES ('xxx') 
    
    INSERT INTO @starnet VALUES ('xxx') 
    DECLARE @entityID int = {}
    
    IF @entityID = 10833
    BEGIN
    
    SELECT COUNT(DISTINCT(pol_num)) In_Force_Count, sum(lmt_pol_s) Exposure
    FROM xxx
    WHERE aslob = {}
    and CONCAT({},1231) between CAST(d_pol_eff AS DATE) and CAST(d_pol_exp AS DATE)
    and cvg_state = '{}'
    and rpt_co_name in (SELECT * FROM @xxx)
    
    END
    
    IF @entityID = 25224
    BEGIN
    
    SELECT COUNT(DISTINCT(pol_num)) In_Force_Count, sum(lmt_pol_s) Exposure
    FROM xxx
    WHERE aslob = {}
    and CONCAT({},1231) between CAST(d_pol_eff AS DATE) and CAST(d_pol_exp AS DATE)
    and cvg_state = '{}'
    and rpt_co_name in (SELECT * FROM @xxx)
    
    END
    
    IF @entityID = 29580
    BEGIN
    
    SELECT COUNT(DISTINCT(pol_num)) In_Force_Count, sum(lmt_pol_s) Exposure
    FROM xxx 
    WHERE aslob = {}
    and CONCAT({},1231) between CAST(d_pol_eff AS DATE) and CAST(d_pol_exp AS DATE)
    and cvg_state = '{}'
    and rpt_co_name in (SELECT * FROM @xxx)
    
    END
    
    IF @entityID = 31003
    BEGIN
    
    SELECT COUNT(DISTINCT(pol_num)) In_Force_Count, sum(lmt_pol_s) Exposure
    FROM xxx
    WHERE aslob = {}
    and CONCAT({},1231) between CAST(d_pol_eff AS DATE) and CAST(d_pol_exp AS DATE)
    and cvg_state = '{}'
    and rpt_co_name = 'xxx'
    
    END
    
    IF @entityID = 31295
    BEGIN
    
    SELECT COUNT(DISTINCT(pol_num)) In_Force_Count, sum(lmt_pol_s) Exposure
    FROM xxx
    WHERE aslob = {}
    and CONCAT({},1231) between CAST(d_pol_eff AS DATE) and CAST(d_pol_exp AS DATE)
    and cvg_state = '{}'
    and rpt_co_name = 'xxx'
    
    END
    
    IF @entityID = 32603
    BEGIN
    
    SELECT COUNT(DISTINCT(pol_num)) In_Force_Count, sum(lmt_pol_s) Exposure
    FROM xxx
    WHERE aslob = {}
    and CONCAT({},1231) between CAST(d_pol_eff AS DATE) and CAST(d_pol_exp AS DATE)
    and cvg_state = '{}'
    and rpt_co_name = 'xxx'
    
    END
    
    IF @entityID = 38911
    BEGIN
    
    SELECT COUNT(DISTINCT(pol_num)) In_Force_Count, sum(lmt_pol_s) Exposure
    FROM xxx 
    WHERE aslob = {}
    and CONCAT({},1231) between CAST(d_pol_eff AS DATE) and CAST(d_pol_exp AS DATE)
    and cvg_state = '{}'
    and rpt_co_name = 'xxx'
    
    END
    
    IF @entityID = 40045
    BEGIN
    
    SELECT COUNT(DISTINCT(pol_num)) In_Force_Count, sum(lmt_pol_s) Exposure
    FROM xxx 
    WHERE aslob = {}
    and CONCAT({},1231) between CAST(d_pol_eff AS DATE) and CAST(d_pol_exp AS DATE)
    and cvg_state = '{}'
    and rpt_co_name in (SELECT * FROM @xxx)
    END 
    """.format(data[0], data[2], data[1], data[3], data[2], data[1], 
                  data[3], data[2], data[1], data[3], data[2], data[1], 
                  data[3], data[2], data[1], data[3], data[2], data[1], 
                  data[3], data[2], data[1], data[3], data[2], data[1], data[3])
    
    queryFile.write(query)
    print query
queryFile.close()

# %%
#Runs successfully and does what is expected.

# %%
#Stripped all but 1 query from the file to test. Print out query to see if anything's missing
queryFile = open('C:\Users\\pathtofile\file.csv', 'r')

for line in queryFile:
    fields = line.split('|')
    print fields[0]
#Can's show actual sql on public file

# %%
#Spacing and indents came out a bit odd, but it runs in SSMS. For now, it looks good.

# %%
queryFile = open(queryFile = open('C:\Users\\pathtofile\file.csv', 'r')

for line in queryFile:
    fields = line.split('|')
    print fields[0], 'r')

for line in queryFile:
    fields = line.split('|')
    cursor.execute(fields[0])
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# <ipython-input-82-6cf7fa92ef07> in <module>()
#       3 for line in queryFile:
#       4     fields = line.split('|')
# ----> 5     cursor.execute(fields[0])
#
# ProgrammingError: ('42000', '[42000] [Microsoft][ODBC SQL Server Driver][SQL Server]Must declare the table variable "@gemini". (1087) (SQLExecDirectW)')

# %%
#According to this Stack Overflow post:
#http://stackoverflow.com/questions/13750548/sql-server-variable-declared-but-still-says-must-declare-the-scalar-variable
#there is a workaround but I would have to restructure everything and it may slow down execution. 
#Temp Table test. Runs in SSMS
query = """USE xxx
    CREATE TABLE  #xxx (Value VARCHAR(MAX))
    
    INSERT INTO #xxx VALUES ('xxx') 
    INSERT INTO #xxx VALUES ('xxx') 
    
    CREATE TABLE #xxx (Value VARCHAR(MAX))
    
    INSERT INTO #xxx VALUES ('xxx') 
    INSERT INTO #xxx VALUES ('xxx') 
    
    CREATE TABLE #xxx (Value VARCHAR(MAX))
    
    INSERT INTO #xxx VALUES ('xxx')
    INSERT INTO #xxx VALUES ('xxx') 
    INSERT INTO #xxx VALUES ('xxx') 
    
    CREATE TABLE #xxx (Value VARCHAR(MAX))
    INSERT INTO #xxx VALUES ('xxx') 
    
    INSERT INTO #starnet VALUES ('xxx') 
    DECLARE @entityID int = 10833
    
    IF @entityID = 10833
    BEGIN
    
    SELECT COUNT(DISTINCT(pol_num)) In_Force_Count, sum(lmt_pol_s) Exposure
    FROM xxx
    WHERE aslob = 90
    and CONCAT(2009,1231) between CAST(d_pol_eff AS DATE) and CAST(d_pol_exp AS DATE)
    and cvg_state = 'CA'
    and rpt_co_name in (SELECT * FROM #xxx)
    
    END
    
    IF @entityID = 25224
    BEGIN
    
    SELECT COUNT(DISTINCT(pol_num)) In_Force_Count, sum(lmt_pol_s) Exposure
    FROM xxx
    WHERE aslob = 90
    and CONCAT(2009,1231) between CAST(d_pol_eff AS DATE) and CAST(d_pol_exp AS DATE)
    and cvg_state = 'CA'
    and rpt_co_name in (SELECT * FROM #xxx)
    
    END
    
    IF @entityID = 29580
    BEGIN
    
    SELECT COUNT(DISTINCT(pol_num)) In_Force_Count, sum(lmt_pol_s) Exposure
    FROM xxx
    WHERE aslob = 90
    and CONCAT(2009,1231) between CAST(d_pol_eff AS DATE) and CAST(d_pol_exp AS DATE)
    and cvg_state = 'CA'
    and rpt_co_name in (SELECT * FROM #xxx)
    
    END
    
    IF @entityID = 31003
    BEGIN
    
    SELECT COUNT(DISTINCT(pol_num)) In_Force_Count, sum(lmt_pol_s) Exposure
    FROM xxx 
    WHERE aslob = 90
    and CONCAT(2009,1231) between CAST(d_pol_eff AS DATE) and CAST(d_pol_exp AS DATE)
    and cvg_state = 'CA'
    and rpt_co_name = 'xxx'
    
    END
    
    IF @entityID = 31295
    BEGIN
    
    SELECT COUNT(DISTINCT(pol_num)) In_Force_Count, sum(lmt_pol_s) Exposure
    FROM xxx 
    WHERE aslob = 90
    and CONCAT(2009,1231) between CAST(d_pol_eff AS DATE) and CAST(d_pol_exp AS DATE)
    and cvg_state = 'CA'
    and rpt_co_name = 'xxx'
    
    END
    
    IF @entityID = 32603
    BEGIN
    
    SELECT COUNT(DISTINCT(pol_num)) In_Force_Count, sum(lmt_pol_s) Exposure
    FROM xxx 
    WHERE aslob = 90
    and CONCAT(2009,1231) between CAST(d_pol_eff AS DATE) and CAST(d_pol_exp AS DATE)
    and cvg_state = 'CA'
    and rpt_co_name = 'xxx'
    
    END
    
    IF @entityID = 38911
    BEGIN
    
    SELECT COUNT(DISTINCT(pol_num)) In_Force_Count, sum(lmt_pol_s) Exposure
    FROM xxx
    WHERE aslob = 90
    and CONCAT(2009,1231) between CAST(d_pol_eff AS DATE) and CAST(d_pol_exp AS DATE)
    and cvg_state = 'CA'
    and rpt_co_name = 'xxx'
    
    END
    
    IF @entityID = 40045
    BEGIN
    
    SELECT COUNT(DISTINCT(pol_num)) In_Force_Count, sum(lmt_pol_s) Exposure
    FROM xxx
    WHERE aslob = 90
    and CONCAT(2009,1231) between CAST(d_pol_eff AS DATE) and CAST(d_pol_exp AS DATE)
    and cvg_state = 'CA'
    and rpt_co_name in (SELECT * FROM #xxx)
    END""")

cursor.execute(query)
cursor.fetchall()

# %%
#Too slow. I'm done with tempdb. It's not great friends with pyodbc. I'm making a lookup table.
#Create Lookup Table
query = '''CREATE TABLE NAIC_Legal_Entity_Lookup  (ID int,
                                     Ent_Name VARCHAR(500))

INSERT INTO NAIC_Legal_Entity_Lookup 
VALUES (10833,'xxx'),
       (10833,'xxx xxx xxx'),
       (25224,'xxx xxx'),
       (25224,'xxx xxx xxx xxx'),
       (29580,'xxx xxx'),
       (29580,'xxx xxx xxx xxx'),
       (29580,'xxx'),
       (31003,'xxx xxx xxx xxx xxx xxx'),
       (31295,'xxx xxx xxx xxx xxx'),
       (32603,'xxx xxx xxx'),  
       (38911,'xxx xxx xxx xxx'), 
       (40045,'xxxt'),
       (40045,'xxx xxx xxx')
       '''
cursor.execute(query)

# %%
#Test
cursor.execute('select * from NAIC_Legal_Entity_Lookup')
cursor.fetchall()
#Passed - Can't show names on public file

# %%
#Test
query = '''DECLARE @entityID int = 10833
                  SELECT COUNT(DISTINCT(pol_num)) In_Force_Count, sum(lmt_pol_s) Exposure
                  FROM xxx
                  WHERE aslob = 90
                  and CONCAT(2009,1231) between CAST(d_pol_eff AS DATE) and CAST(d_pol_exp AS DATE)
                  and cvg_state = 'CA'
                  and rpt_co_name in (SELECT Ent_Name FROM NAIC_Legal_Ent_Lookup WHERE ID = @entityID)'''

cursor.execute(query)
cursor.fetchall()
# Out:
# [(2, Decimal('45075000.00'))]

# %%
#From file test

with open('C:/users/pathtofile/file.csv', 'r') as q:
    data = q.read().replace('|', '')
cursor.execute(data)
cursor.fetchall()
# Out:
# [(2, Decimal('45075000.00'))]

# %%
#Moving this down here for easier access
file = open('C:/users/pathtofile/file.csv', 'w')
#file.close()

# %%
#Since the above runs quickly, I'm going to re-write the queries in this format. 
row_iterator = df.iterrows()
_, last = row_iterator.next()  # take first item from row_iterator

for i, row in row_iterator:
    row1 = (int(row['LEGAL_ENTITY']), int(row['CY_YE']), int(row['TRIP_ASLOB']), row['CVG_ST'])
    row2 = (last['LEGAL_ENTITY'], last['CY_YE'], last['TRIP_ASLOB'], last['CVG_ST'])
    last = row
    data = row1
    
    query= """SELECT COUNT(DISTINCT(pol_num)) In_Force_Count, sum(distinct(lmt_pol_s)) Exposure
              FROM bapu.dbo.xxx
              WHERE aslob = {}
              and CONCAT({},1231) between CAST(d_pol_eff AS DATE) and CAST(d_pol_exp AS DATE)
              and cvg_state = '{}'
              and rpt_co_name in (SELECT Ent_Name FROM NAIC_Legal_Ent_Lookup WHERE ID = {})
              |""".format(data[2],data[1],data[3], data[0])
    
    file.write(query)
#passed

# %%
#Added row number
#Before testing the file, I want to see how quickly results are returned directly from Juppyter. 

row_iterator = df.iterrows()
_, last = row_iterator.next()  # take first item from row_iterator

for i, row in row_iterator:
    row1 = (int(row['LEGAL_ENTITY']), int(row['CY_YE']), int(row['TRIP_ASLOB']), row['CVG_ST'], int(row['Row']))
    row2 = (last['LEGAL_ENTITY'], last['CY_YE'], last['TRIP_ASLOB'], last['CVG_ST'], int(row['Row']))
    last = row
    data = row1
    query= """SELECT COUNT(DISTINCT(pol_num)) In_Force_Count, sum(distinct(lmt_pol_s)) Exposure
              FROM bapu.dbo.xxx
              WHERE aslob = {}
              and CONCAT({},1231) between CAST(d_pol_eff AS DATE) and CAST(d_pol_exp AS DATE)
              and cvg_state = '{}'
              and rpt_co_name in (SELECT Ent_Name FROM NAIC_Legal_Ent_Lookup WHERE ID = {})
              and (cvg_desc = 'tria' or cvg_desc like '%terrorism%')
              """.format(data[2],data[1],data[3], data[0])
    cursor.execute(query)
    for row in cursor.fetchall():
        #print row[0], row[1], data[2], data[1], data[3], data[0], data[4]
#passed - Can't show data on public file

# %%
#Runs pretty quickly. Writing TRIA results to result file
row_iterator = df.iterrows()
_, last = row_iterator.next()  # take first item from row_iterator
resultFile = open('C:\\Users\\pathtofile\\file.csv', 'w')

for i, row in row_iterator:
    row1 = (int(row['LEGAL_ENTITY']), int(row['CY_YE']), int(row['TRIP_ASLOB']), row['CVG_ST'], int(row['Row']))
    row2 = (last['LEGAL_ENTITY'], last['CY_YE'], last['TRIP_ASLOB'], last['CVG_ST'], int(row['Row']))
    last = row
    data = row1
    query= """SELECT COUNT(DISTINCT(pol_num)) In_Force_Count, sum(distinct(lmt_pol_s)) Exposure
              FROM bapu.dbo.xxx
              WHERE aslob = {}
              and CONCAT({},1231) between CAST(d_pol_eff AS DATE) and CAST(d_pol_exp AS DATE)
              and cvg_state = '{}'
              and rpt_co_name in (SELECT Ent_Name FROM NAIC_Legal_Ent_Lookup WHERE ID = {})
              and (cvg_desc = 'tria' or cvg_desc like '%terrorism%')
              """.format(data[2],data[1],data[3], data[0])
    cursor.execute(query)
    for row in cursor.fetchall():
        resultFile.write("{} {} {} {} {} {} {} \n".format(row[0], row[1], data[2], data[1], data[3], data[0], data[4]))
        print row[0], row[1], data[2], data[1], data[3], data[0], data[4]

# %%
#That worked well. Doing the same for the State file. Get file and transform to data frame
f2 = open('C:\Users\\pathtofile\\file.csv')
file2 = pd.read_csv(f2)
df2 = pd.DataFrame(file2)

# %%
# Check data
df2.head()
# Out:
#    Row  LEGAL_ENTITY  CY_YE CVG_ST
# 0    1         10833   2008     PR
# 1    2         10833   2009     CA
# 2    3         10833   2009     ID
# 3    4         10833   2009     PR
# 4    5         10833   2010     CA

# %%
#Writing STATE results to result file
row_iterator = df2.iterrows()
_, last = row_iterator.next()  # take first item from row_iterator
resultFile = open('C:\Users\\pathtofile\\file.csv', 'w')
for i, row in row_iterator:
    row1 = (int(row['LEGAL_ENTITY']), int(row['CY_YE']), row['CVG_ST'], int(row['Row']))
    row2 = (last['LEGAL_ENTITY'], last['CY_YE'], last['CVG_ST'], int(row['Row']))
    last = row
    data = row1
    query= """SELECT COUNT(DISTINCT(pol_num)) In_Force_Count, sum(distinct(lmt_pol_s)) Exposure
              FROM bapu.dbo.xxx
              WHERE CONCAT({},1231) between CAST(d_pol_eff AS DATE) and CAST(d_pol_exp AS DATE)
              and cvg_state = '{}'
              and rpt_co_name in (SELECT Ent_Name FROM NAIC_Legal_Ent_Lookup WHERE ID = {})
              and (cvg_desc = 'tria' or cvg_desc like '%terrorism%')
              """.format(data[1],data[2],data[0])
    cursor.execute(query)
    for row in cursor.fetchall():
        resultFile.write("{} {} {} {} {} {} \n".format(row[0], row[1], data[1], data[2], data[0], data[3]))
        print row[0], row[1], data[1], data[2], data[0], data[3]
# Out:
# 0 None 2009 CA 10833 2
# 0 None 2009 ID 10833 3
# 0 None 2009 PR 10833 4
# 2 5250000.00 2010 CA 10833 5
# 0 None 2010 FL 10833 6
# 0 None 2010 ID 10833 7
# 2 1500000.00 2010 NY 10833 8
# 0 None 2010 PR 10833 9
# 4 12125000.00 2011 CA 10833 10
# 0 None 2011 FL 10833 11
# 0 None 2011 ID 10833 12
# 6 93574000.00 2011 NY 10833 13
# 1 500000.00 2011 PR 10833 14
# 4 12125000.00 2012 CA 10833 15
# 1 75000.00 2012 GA 10833 16
# 9 39777270.00 2012 NY 10833 17
# 1 250000.00 2012 PR 10833 18
# 1 5000000.00 2012 TN 10833 19
# 1 3000000.00 2013 CA 10833 20
# 0 None 2013 GA 10833 21
# 4 28000000.00 2013 NY 10833 22
# 2 75250000.00 2013 PR 10833 23
# 0 None 2013 TN 10833 24
# 0 None 2014 CA 10833 25
# 3 11000000.00 2014 NY 10833 26
# 2 75250000.00 2014 PR 10833 27
# 2 13000000.00 2015 NY 10833 28
# 1 250000.00 2015 PR 10833 29
# 0 None 2016 NY 10833 30
# 1 250000.00 2016 PR 10833 31
# 2 7207911.00 2008 FL 25224 32
# 5 32659422.00 2008 MA 25224 33
# 0 None 2008 MN 25224 34
# 1 20837928.00 2008 MO 25224 35
# 1 2118000.00 2008 NC 25224 36
# 3 16700000.00 2009 FL 25224 37
# 1 4500000.00 2009 MA 25224 38
# 0 None 2009 MN 25224 39
# 0 None 2009 MO 25224 40
# 1 2118000.00 2009 NC 25224 41
# 2 3000000.00 2016 MI 29580 190
# 0 None 2016 MN 29580 191
# 1 3120000.00 2016 MO 29580 192
# 2 2500000.00 2016 MS 29580 193
# 9 9712000.00 2016 NC 29580 194
# 1 500000.00 2016 NE 29580 195
# 14 17120000.00 2016 NJ 29580 196
# 3 6500000.00 2016 NV 29580 197
# 193 92217646.00 2016 NY 29580 198
# 6 4080000.00 2016 OH 29580 199
# 2 4500000.00 2016 OK 29580 200
# 2 1000000.00 2016 OR 29580 201
# 13 17584845.00 2016 PA 29580 202
# 1 500000.00 2016 SC 29580 203
# 6 3500000.00 2016 TN 29580 204
# 47 12740000.00 2016 TX 29580 205
# 1 2000000.00 2016 UT 29580 206
# 4 1500000.00 2016 VA 29580 207
# 2 5120000.00 2016 WA 29580 208
# 1 3000000.00 2016 WI 29580 209
# 1 500000.00 2016 WV 29580 210
# 4 1500000.00 2014 AL 31003 211
# 1 500000.00 2014 AR 31003 212
# 1 1000000.00 2014 AZ 31003 213
# 3 1000000.00 2014 CA 31003 214
# 2 500000.00 2014 CT 31003 215
# 1 500000.00 2014 DC 31003 216
# 8 1500000.00 2014 GA 31003 217
# 6 500000.00 2014 IL 31003 218
# 3 1500000.00 2014 IN 31003 219
# 2 500000.00 2014 KS 31003 220
# 1 500000.00 2014 LA 31003 221
# 1 500000.00 2014 MD 31003 222
# 2 1500000.00 2014 MI 31003 223
# 4 1500000.00 2014 NC 31003 224
# 1 500000.00 2014 NH 31003 225
# 1 1000000.00 2014 NJ 31003 226
# 1 1000000.00 2014 NV 31003 227
# 3 1500000.00 2014 NY 31003 228
# 7 1500000.00 2014 PA 31003 229
# 1 1000000.00 2014 SC 31003 230
# 1 500000.00 2014 TN 31003 231
# 3 1000000.00 2014 TX 31003 232
# 7 1500000.00 2014 VA 31003 233
# 1 500000.00 2014 WV 31003 234
# 12 1500000.00 2015 AL 31003 235
# 1 500000.00 2015 AR 31003 236
# 0 None 2015 AZ 31003 237
# 11 1000000.00 2015 CA 31003 238
# 1 500000.00 2015 CO 31003 239
# 1 500000.00 2015 CT 31003 240
# 1 500000.00 2015 DC 31003 241
# 22 1500000.00 2015 GA 31003 242
# 18 500000.00 2015 IL 31003 243
# 6 1500000.00 2015 IN 31003 244
# 7 1500000.00 2015 KS 31003 245
# 3 500000.00 2015 KY 31003 246
# 5 1500000.00 2015 LA 31003 247
# 1 500000.00 2015 MA 31003 248
# 3 500000.00 2015 MD 31003 249
# 5 1500000.00 2015 MI 31003 250
# 2 500000.00 2015 MN 31003 251
# 2 500000.00 2015 MO 31003 252
# 4 500000.00 2015 MS 31003 253
# 14 1500000.00 2015 NC 31003 254
# 1 500000.00 2015 NH 31003 255
# 1 1000000.00 2015 NJ 31003 256
# 3 1500000.00 2015 NM 31003 257
# 3 1500000.00 2015 NV 31003 258
# 19 1500000.00 2015 NY 31003 259
# 1 1000000.00 2015 OK 31003 260
# 8 1500000.00 2015 PA 31003 261
# 3 1500000.00 2015 SC 31003 262
# 5 500000.00 2015 TN 31003 263
# 4 1000000.00 2015 TX 31003 264
# 5 276401000.00 2012 WI 40045 1018
# 1 2500000.00 2012 WV 40045 1019
# 3 2568166.00 2012 WY 40045 1020
# 1 265000.00 2013 AK 40045 1021
# 30 55050000.00 2013 AL 40045 1022
# 6 13150000.00 2013 AR 40045 1023
# 28 36062000.00 2013 AZ 40045 1024
# 209 267927168.00 2013 CA 40045 1025
# 15 70230259.00 2013 CO 40045 1026
# 72 269464417.00 2013 CT 40045 1027
# 16 233607709.00 2013 DC 40045 1028
# 6 88500000.00 2013 DE 40045 1029
# 103 104463698.00 2013 FL 40045 1030
# 69 91833726.00 2013 GA 40045 1031
# 1 1125865.00 2013 HI 40045 1032
# 7 20363600.00 2013 IA 40045 1033
# 0 None 2013 ID 40045 1034
# 109 418118036.00 2013 IL 40045 1035
# 9 138158000.00 2013 IN 40045 1036
# 14 24455750.00 2013 KS 40045 1037
# 10 11226213.00 2013 KY 40045 1038
# 15 11035000.00 2013 LA 40045 1039
# 91 329974497.00 2013 MA 40045 1040
# 30 84767585.00 2013 MD 40045 1041
# 17 62944007.00 2013 ME 40045 1042
# 21 149471800.00 2013 MI 40045 1043
# 17 37948060.00 2013 MN 40045 1044
# 29 404174393.00 2013 MO 40045 1045
# 1 100000.00 2013 MS 40045 1046
# 5 5172890.00 2013 MT 40045 1047
# 35 77769043.00 2013 NC 40045 1048
# 0 None 2013 ND 40045 1049
# 3 4101700.00 2013 NE 40045 1050
# 17 75182100.00 2013 NH 40045 1051
# 64 101033840.00 2013 NJ 40045 1052
# 31 122070182.00 2013 NM 40045 1053
# 5 3235000.00 2013 NV 40045 1054
# 939 1539662995.00 2013 NY 40045 1055
# 34 134379500.00 2013 OH 40045 1056
# 8 5105093.00 2013 OK 40045 1057
# 7 4950000.00 2013 OR 40045 1058
# 66 184068560.00 2013 PA 40045 1059
# 0 None 2013 PR 40045 1060
# 8 163165374.00 2013 RI 40045 1061
# 29 22923490.00 2013 SC 40045 1062
# 3 1545000.00 2013 SD 40045 1063
# 28 102052523.00 2013 TN 40045 1064
# 147 263091813.00 2013 TX 40045 1065
# 8 6995700.00 2013 UT 40045 1066
# 14 5255000.00 2013 VA 40045 1067
# 14 6566615.00 2013 VT 40045 1068
# 15 112416208.00 2013 WA 40045 1069
# 6 102314028.00 2013 WI 40045 1070
# 2 26500000.00 2013 WV 40045 1071
# 5 60205773.00 2013 WY 40045 1072
# 1 265000.00 2014 AK 40045 1073
# 28 62131909.00 2014 AL 40045 1074
# 6 13150000.00 2014 AR 40045 1075
# 42 52425500.00 2014 AZ 40045 1076
# 257 324508550.00 2014 CA 40045 1077
# 17 20192259.00 2014 CO 40045 1078
# 76 251910390.00 2014 CT 40045 1079
# 14 261278738.00 2014 DC 40045 1080
# 6 43500000.00 2014 DE 40045 1081
# 106 132833850.00 2014 FL 40045 1082
# 92 132759160.00 2014 GA 40045 1083
# 1 1125865.00 2014 HI 40045 1084
# 9 13593600.00 2014 IA 40045 1085
# 0 None 2014 ID 40045 1086
# 112 371021720.00 2014 IL 40045 1087
# 16 142522620.00 2014 IN 40045 1088
# 20 18719250.00 2014 KS 40045 1089
# 12 14458338.00 2014 KY 40045 1090
# 17 11711000.00 2014 LA 40045 1091
# 102 421040144.00 2014 MA 40045 1092
# 28 95413185.00 2014 MD 40045 1093
# 21 74336170.00 2014 ME 40045 1094
# 24 25659000.00 2014 MI 40045 1095
# 20 44193086.00 2014 MN 40045 1096
# 31 42997700.00 2014 MO 40045 1097
# 3 2180000.00 2014 MS 40045 1098
# 4 5187450.00 2014 MT 40045 1099
# 33 74104243.00 2014 NC 40045 1100
# 1 200000.00 2014 ND 40045 1101
# 2 2900000.00 2014 NE 40045 1102
# 19 65742158.00 2014 NH 40045 1103
# 73 105816840.00 2014 NJ 40045 1104
# 47 184344904.00 2014 NM 40045 1105
# 9 6816877.00 2014 NV 40045 1106
# 953 1592344704.00 2014 NY 40045 1107
# 48 144024501.00 2014 OH 40045 1108
# 9 66567000.00 2014 OK 40045 1109
# 11 6325000.00 2014 OR 40045 1110
# 78 311367710.00 2014 PA 40045 1111
# 6 86070202.00 2014 RI 40045 1112
# 39 23883490.00 2014 SC 40045 1113
# 5 3985000.00 2014 SD 40045 1114
# 35 102381155.00 2014 TN 40045 1115
# 166 214808123.00 2014 TX 40045 1116
# 11 8714000.00 2014 UT 40045 1117
# 16 15583810.00 2014 VA 40045 1118
# 18 7366616.00 2014 VT 40045 1119
# 20 112803200.00 2014 WA 40045 1120
# 6 105919609.00 2014 WI 40045 1121
# 3 26770000.00 2014 WV 40045 1122
# 4 6549283.00 2014 WY 40045 1123
# 2 299000.00 2015 AK 40045 1124
# 26 59781292.00 2015 AL 40045 1125
# 6 21950000.00 2015 AR 40045 1126
# 44 47423000.00 2015 AZ 40045 1127
# 271 212069600.00 2015 CA 40045 1128
# 20 12272259.00 2015 CO 40045 1129
# 89 177497601.00 2015 CT 40045 1130
# 11 70971622.00 2015 DC 40045 1131
# 6 44500000.00 2015 DE 40045 1132
# 118 65714400.00 2015 FL 40045 1133
# 101 141756901.00 2015 GA 40045 1134
# 4 1477000.00 2015 HI 40045 1135
# 7 14618600.00 2015 IA 40045 1136
# 3 9100000.00 2015 ID 40045 1137
# 111 229356835.00 2015 IL 40045 1138
# 18 88379295.00 2015 IN 40045 1139
# 22 23570250.00 2015 KS 40045 1140
# 11 28218418.00 2015 KY 40045 1141
# 20 15471900.00 2015 LA 40045 1142
# 105 219157390.00 2015 MA 40045 1143
# 29 84839360.00 2015 MD 40045 1144
# 18 67867101.00 2015 ME 40045 1145
# 28 82517662.00 2015 MI 40045 1146
# 28 49757691.00 2015 MN 40045 1147
# 26 35294174.00 2015 MO 40045 1148
# 4 2655000.00 2015 MS 40045 1149
# 3 4187450.00 2015 MT 40045 1150
# 34 55654178.00 2015 NC 40045 1151
# 4 3555000.00 2015 ND 40045 1152
# 3 2900000.00 2015 NE 40045 1153
# 18 66486000.00 2015 NH 40045 1154
# 83 110770941.10 2015 NJ 40045 1155
# 55 132272742.00 2015 NM 40045 1156
# 8 11281877.00 2015 NV 40045 1157
# 974 1195404259.01 2015 NY 40045 1158
# 67 108023001.00 2015 OH 40045 1159
# 11 61806043.00 2015 OK 40045 1160
# 10 4980000.00 2015 OR 40045 1161
# 74 249413037.00 2015 PA 40045 1162
# 7 60871319.00 2015 RI 40045 1163
# 39 24774560.00 2015 SC 40045 1164
# 5 3739800.00 2015 SD 40045 1165
# 46 109132749.01 2015 TN 40045 1166
# 178 174637935.01 2015 TX 40045 1167
# 11 8300000.00 2015 UT 40045 1168
# 15 45068810.00 2015 VA 40045 1169
# 13 12131500.00 2015 VT 40045 1170
# 22 87474895.00 2015 WA 40045 1171
# 8 54724712.00 2015 WI 40045 1172
# 3 26770000.00 2015 WV 40045 1173
# 4 6500000.00 2015 WY 40045 1174
# 4 4368600.00 2016 AK 40045 1175
# 24 69195683.00 2016 AL 40045 1176
# 6 23147895.00 2016 AR 40045 1177
# 46 50352000.00 2016 AZ 40045 1178
# 279 225661600.00 2016 CA 40045 1179
# 23 49135000.00 2016 CO 40045 1180
# 91 196693998.00 2016 CT 40045 1181
# 11 79094349.00 2016 DC 40045 1182
# 6 48500000.00 2016 DE 40045 1183
# 129 67863600.00 2016 FL 40045 1184
# 153 126792709.00 2016 GA 40045 1185
# 4 1950000.00 2016 HI 40045 1186
# 7 14443600.00 2016 IA 40045 1187
# 9 16350000.00 2016 ID 40045 1188
# 108 219637739.00 2016 IL 40045 1189
# 21 97182040.00 2016 IN 40045 1190
# 19 20220000.00 2016 KS 40045 1191
# 14 30721418.00 2016 KY 40045 1192
# 17 11710900.00 2016 LA 40045 1193
# 109 223686171.00 2016 MA 40045 1194
# 31 91577000.00 2016 MD 40045 1195
# 21 66723849.00 2016 ME 40045 1196
# 31 91298289.00 2016 MI 40045 1197
# 33 54263080.00 2016 MN 40045 1198
# 24 67455474.00 2016 MO 40045 1199
# 4 2555000.00 2016 MS 40045 1200
# 4 9100000.00 2016 MT 40045 1201
# 29 54127743.00 2016 NC 40045 1202
# 4 3500000.00 2016 ND 40045 1203
# 3 2960000.00 2016 NE 40045 1204
# 13 62785000.00 2016 NH 40045 1205
# 96 151832956.00 2016 NJ 40045 1206
# 65 144073055.00 2016 NM 40045 1207
# 12 14285000.00 2016 NV 40045 1208
# 967 1065711922.01 2016 NY 40045 1209
# 67 114685000.00 2016 OH 40045 1210
# 12 63954568.00 2016 OK 40045 1211
# 10 7930000.00 2016 OR 40045 1212
# 82 205940632.00 2016 PA 40045 1213
# 1 250000.00 2016 PR 40045 1214
# 7 53060612.00 2016 RI 40045 1215
# 36 25085235.00 2016 SC 40045 1216
# 3 1375000.00 2016 SD 40045 1217
# 44 112426349.01 2016 TN 40045 1218
# 193 209854328.01 2016 TX 40045 1219
# 13 13460000.00 2016 UT 40045 1220
# 17 51728810.00 2016 VA 40045 1221
# 14 16178000.00 2016 VT 40045 1222
# 18 80746480.00 2016 WA 40045 1223
# 12 54980000.00 2016 WI 40045 1224
# 3 26770000.00 2016 WV 40045 1225
# 4 6900000.00 2016 WY 40045 1226

# %%
#Done.
